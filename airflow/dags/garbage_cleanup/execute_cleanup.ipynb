# %%
import pandas as pd
import mysql.connector
from fuzzywuzzy import process

# %%
sexual_orientation_validations = [
    "ASEXUAL",
    "BISEXUAL",
    "DEMISEXUAL",
    "GAY",
    "HETEROSEXUAL",
    "LESBIAN",
    "PANSEXUAL",
    "QUEER",
    "OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

gender_validations = [
    "MALE",
    "FEMALE",
    "TRANSGENDER",
    "NON-BINARY",
    "OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

disability_validations = [
    "NO KNOWN DISABILITY",
    "A SPECIFIC LEARNING DIFFICULTY SUCH AS DYSLEXIA, DYSPRAXIA OR AD(H)D",
    "A SOCIAL/COMMUNICATION IMPAIRMENT SUCH AS ASPERGER'S SYNDROME/OTHER AUTISTIC SPECTRUM DISORDER",
    "A LONG STANDING ILLNESS OR HEALTH CONDITION SUCH AS CANCER, HIV, DIABETES, CHRONIC HEART DISEASE, OR EPILEPSY",
    "A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER",
    "A PHYSICAL IMPAIRMENT OR MOBILITY ISSUES, SUCH AS DIFFICULTY USING ARMS OR USING A WHEELCHAIR OR CRUTCHES",
    "DEAF OR A SERIOUS HEARING IMPAIRMENT",
    "BLIND OR A SERIOUS VISUAL IMPAIRMENT UNCORRECTED BY GLASSES",
    "A DISABILITY, IMPAIRMENT OR MEDICAL CONDITION THAT IS NOT LISTED",
    "INFORMATION REFUSED",
    "NOT AVAILABLE",
    "OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

religion_validations = [
    "ATHEISM",
    "BUDDHISM",
    "CHRISTIANITY",
    "HINDUISM",
    "ISLAM",
    "JUDAISM",
    "SIKHISM",
    "OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

ethnicity_validations = [
    "AFRICAN",
    "ANY OTHER ASIAN BACKGROUND",
    "ANY OTHER BLACK, BLACK BRITISH, OR CARIBBEAN BACKGROUND",
    "ANY OTHER MIXED OR MULTIPLE ETHNIC BACKGROUND",
    "ANY OTHER WHITE BACKGROUND",
    "ARAB",
    "BANGLADESHI",
    "CARIBBEAN",
    "CHINESE",
    "ENGLISH, WELSH, SCOTTISH, NORTHERN IRISH OR BRITISH",
    "GYPSY OR IRISH TRAVELLER",
    "INDIAN",
    "IRISH",
    "PAKISTANI",
    "ROMA",
    "WHITE AND ASIAN",
    "WHITE AND BLACK AFRICAN",
    "WHITE AND BLACK CARIBBEAN",
    "OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

nationality_validations = [
    "1-BRITISH",
    "2-AFGHAN",
    "3-ALBANIAN",
    "4-ALGERIAN",
    "5-AMERICAN",
    "6-ANDORRAN",
    "7-ANGOLAN",
    "8-ANTIGUANS",
    "9-ARGENTINEAN",
    "10-ARMENIAN",
    "11-AUSTRALIAN",
    "12-AUSTRIAN",
    "13-AZERBAIJANI",
    "14-BAHAMIAN",
    "15-BAHRAINI",
    "16-BANGLADESHI",
    "17-BARBADIAN",
    "18-BARBUDANS",
    "19-BATSWANA",
    "20-BELARUSIAN",
    "21-BELGIAN",
    "22-BELIZEAN",
    "23-BENINESE",
    "24-BHUTANESE",
    "25-BOLIVIAN",
    "26-BOSNIAN",
    "27-BRAZILIAN",
    "28-BRUNEIAN",
    "29-BULGARIAN",
    "30-BURKINABE",
    "31-BURMESE",
    "32-BURUNDIAN",
    "33-CAMBODIAN",
    "34-CAMEROONIAN",
    "35-CANADIAN",
    "36-CAPE VERDEAN",
    "37-CENTRAL AFRICAN",
    "38-CHADIAN",
    "39-CHILEAN",
    "40-CHINESE",
    "41-COLOMBIAN",
    "42-COMORAN",
    "43-CONGOLESE",
    "44-COSTA RICAN",
    "45-CROATIAN",
    "46-CUBAN",
    "47-CYPRIOT",
    "48-CZECH",
    "49-DANISH",
    "50-DJIBOUTI",
    "51-DOMINICAN",
    "52-DUTCH",
    "53-EAST TIMORESE",
    "54-ECUADOREAN",
    "55-EGYPTIAN",
    "56-EMIRIAN",
    "57-EQUATORIAL GUINEAN",
    "58-ERITREAN",
    "59-ESTONIAN",
    "60-ETHIOPIAN",
    "61-FIJIAN",
    "62-FILIPINO",
    "63-FINNISH",
    "64-FRENCH",
    "65-GABONESE",
    "66-GAMBIAN",
    "67-GEORGIAN",
    "68-GERMAN",
    "69-GHANAIAN",
    "70-GREEK",
    "71-GRENADIAN",
    "72-GUATEMALAN",
    "73-GUINEA-BISSAUAN",
    "74-GUINEAN",
    "75-GUYANESE",
    "76-HAITIAN",
    "77-HERZEGOVINIAN",
    "78-HONDURAN",
    "79-HUNGARIAN",
    "80-I-KIRIBATI",
    "81-ICELANDER",
    "82-INDIAN",
    "83-INDONESIAN",
    "84-IRANIAN",
    "85-IRAQI",
    "86-IRISH",
    "87-ISRAELI",
    "88-ITALIAN",
    "89-IVORIAN",
    "90-JAMAICAN",
    "91-JAPANESE",
    "92-JORDANIAN",
    "93-KAZAKHSTANI",
    "94-KENYAN",
    "95-KITTIAN AND NEVISIAN",
    "96-KUWAITI",
    "97-KYRGYZ",
    "98-LAOTIAN",
    "99-LATVIAN",
    "100-LEBANESE",
    "101-LIBERIAN",
    "102-LIBYAN",
    "103-LIECHTENSTEINER",
    "104-LITHUANIAN",
    "105-LUXEMBOURGER",
    "106-MACEDONIAN",
    "107-MALAGASY",
    "108-MALAWIAN",
    "109-MALAYSIAN",
    "110-MALDIVIAN",
    "111-MALIAN",
    "112-MALTESE",
    "113-MARSHALLESE",
    "114-MAURITANIAN",
    "115-MAURITIAN",
    "116-MEXICAN",
    "117-MICRONESIAN",
    "118-MOLDOVAN",
    "119-MONACAN",
    "120-MONGOLIAN",
    "121-MOROCCAN",
    "122-MOSOTHO",
    "123-MOTSWANA",
    "124-MOZAMBICAN",
    "125-NAMIBIAN",
    "126-NAURUAN",
    "127-NEPALESE",
    "128-NEW ZEALANDER",
    "129-NI-VANUATU",
    "130-NICARAGUAN",
    "131-NIGERIAN",
    "132-NIGERIEN",
    "133-NORTH KOREAN",
    "134-NORTHERN IRISH",
    "135-NORWEGIAN",
    "136-OMANI",
    "137-PAKISTANI",
    "138-PALAUAN",
    "139-PANAMANIAN",
    "140-PAPUA NEW GUINEAN",
    "141-PARAGUAYAN",
    "142-PERUVIAN",
    "143-POLISH",
    "144-PORTUGUESE",
    "145-QATARI",
    "146-ROMANIAN",
    "147-RUSSIAN",
    "148-RWANDAN",
    "149-SAINT LUCIAN",
    "150-SALVADORAN",
    "151-SAMOAN",
    "152-SAN MARINESE",
    "153-SAO TOMEAN",
    "154-SAUDI",
    "155-SCOTTISH",
    "156-SENEGALESE",
    "157-SERBIAN",
    "158-SEYCHELLOIS",
    "159-SIERRA LEONEAN",
    "160-SINGAPOREAN",
    "161-SLOVAKIAN",
    "162-SLOVENIAN",
    "163-SOLOMON ISLANDER",
    "164-SOMALI",
    "165-SOUTH AFRICAN",
    "166-SOUTH KOREAN",
    "167-SPANISH",
    "168-SRI LANKAN",
    "169-SUDANESE",
    "170-SURINAMER",
    "171-SWAZI",
    "172-SWEDISH",
    "173-SWISS",
    "174-SYRIAN",
    "175-TAIWANESE",
    "176-TAJIK",
    "177-TANZANIAN",
    "178-THAI",
    "179-TOGOLESE",
    "180-TONGAN",
    "181-TRINIDADIAN OR TOBAGONIAN",
    "182-TUNISIAN",
    "183-TURKISH",
    "184-TUVALUAN",
    "185-UGANDAN",
    "186-UKRAINIAN",
    "187-URUGUAYAN",
    "188-UZBEKISTANI",
    "189-VENEZUELAN",
    "190-VIETNAMESE",
    "191-WELSH",
    "192-YEMENITE",
    "193-ZAMBIAN",
    "194-ZIMBABWEAN",
    "195-OTHER OR NON-DISCLOSURE",
    "UNKNOWN"
]

spoken_language_validations = [
    "ARABIC",
    "BENGALI",
    "CHINESE",
    "DUTCH",
    "ENGLISH",
    "FILIPINO",
    "FRENCH",
    "GERMAN",
    "HINDI",
    "ITALIAN",
    "JAPANESE",
    "KOREAN",
    "MARATHI",
    "OTHER",
    "PERSIAN",
    "POLISH",
    "PORTUGUESE",
    "RUSSIAN",
    "SPANISH",
    "TAMIL",
    "TELUGU",
    "THAI",
    "TURKISH",
    "UKRAINIAN",
    "URDU",
    "VIETNAMESE",
    "OTHER OR NON-DISCLOSURE",
    "ROMANIAN",
    "UNKNOWN"
]

def fuzzy_lookup(x, column):
    
    if column == "SexualOrientation":
        match = process.extractOne(x, sexual_orientation_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if column == "Gender":
        match = process.extractOne(x, gender_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if column == "Disability":
        match = process.extractOne(x, disability_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if column == "Religion":
        match = process.extractOne(x, disability_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if column == "Nationality":
        match = process.extractOne(x, nationality_validations)
        best_match = match[0]
        similarity_score = match[1]
        
    if column == "Ethnicity":
        match = process.extractOne(x, ethnicity_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if column == "SpokenLanguage":
        match = process.extractOne(x, spoken_language_validations)
        best_match = match[0]
        similarity_score = match[1]
    
    if similarity_score >= 90:
        return str(best_match)
    else: 
        return "OTHER OR NON-DISCLOSURE"

# %%
def replace_text(text):
  """Escapes single quotes within a string for safe MySQL insertion."""
  return text.replace("'", "\\'")

def cleanup_yearly_tenant_data(host, user, root_pass, base_table, fpath):
    """_docstring
    
    """

    column_checks = ['SexualOrientation', 'Disability', 'Gender', 'Religion', 'Nationality', 'Ethnicity', 'SpokenLanguage']

    for column in column_checks:
        
        # Establish connection to base
        base_db = mysql.connector.connect(
            host=host,
            user=user,
            password=root_pass,
            database='base'
        )

        # attached to base
        base_cursor = base_db.cursor()

        # df = pd.read_excel(fpath, sheet_name=column)
        # df = df.drop_duplicates()
        
        base_query = f"select {column} from {base_table};"
        base_cursor.execute(base_query)

        # Fetch all the results
        base_result = base_cursor.fetchall()

        # Convert the result to a dataframe
        df = pd.DataFrame(base_result, columns=base_cursor.column_names)
        df = df.drop_duplicates()
        
        for _, row in df.iterrows():
            
            input_value = replace_text(str(row[column]))
            resolved_value = replace_text(fuzzy_lookup(input_value, column))
            
            if input_value != resolved_value:
                try:
                    # Update the table via garbage collector
                    query = f"""
                    UPDATE base.yearly_tenant_data 
                    SET {column} = CASE 
                        WHEN {column} IN ('{input_value}') THEN '{resolved_value}' 
                        ELSE {column} 
                    END;            
                    """
                    
                    # create_query = row['Query']
                    base_cursor.execute(query)
                    print(f"Executed -> {query}")
                except Exception as e:
                    print(f"Err: {e}")
        
        # commit changes and close connections
        base_db.commit()
        base_cursor.close()
        base_db.close()
        


if __name__ == "__main__":

    # prepare the details to connect to the databases
    host = "localhost"
    user = "root"
    root_pass = "admin"
    base_table = 'yearly_tenant_data'
    fpath = "/mnt/c/Users/ASHA Server/repo/source/workspace/garbage-collector/garbage-cleanup-tool.xlsm"
    
    cleanup_yearly_tenant_data(host=host, user=user, root_pass=root_pass, base_table=base_table, fpath=fpath)
# Out:
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('OTHER') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('FEMALE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('hETEROSEXUAL') THEN 'HETEROSEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('NO') THEN 'UNKNOWN'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('TRANS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Heterosexual') THEN 'HETEROSEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Transgender') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Prefer not to say') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Lesbian') THEN 'LESBIAN'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Tenant did not want to disclose') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('HETEROSEX') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Hetrosexual') THEN 'HETEROSEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('A-Sexual') THEN 'ASEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('heterosexual') THEN 'HETEROSEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Bisexual') THEN 'BISEXUAL'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Other') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('NON') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('PREFER NOT TO SAY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SexualOrientation = CASE
#                         WHEN SexualOrientation IN ('Gay') THEN 'GAY'
#                         ELSE SexualOrientation
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('UNDISCLOSED') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('LIVER AND KIDNEY FAILURE HAS PACE MAKER FITTED') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HAS KNEE PROBLEM, HAS DIABETIES') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION AND ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION, ANXIETY, NECK PROBLEMS/PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY/DEPRESSION/PIN AND PLATE IN RIGHT SIDE OF HIP') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('KNEE ISSUE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('STUTTER WITH SPEECH') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('N/A') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY/ DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('UNDIAGNOSED DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('CONSTRUCTED RIGHT LEG/ ADHD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/ PTSD/ DSYLEXIA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('AUTISM/ DEPRESSION/ BPD/ SOCIAL ANXIETY DISORDER') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ATHSMA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('AUTISIC') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANTI-SOCIAL PERSONALITY DISORDER/SOCIAL ANXIETY/ CAFEIONX LEFT EYE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BACK PAINS/HIGH BLOOD PRESSURE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BIB MOBILITY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('LOWER BACK PAIN AND JOINT PAIN/ DEPRESSION/ HIGH BLOOD PRESSURE/ HIGH CHOLESTEROL') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('AUTISM/ LEARNING DISABILTIY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('OSTEOARTHITUS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY AND DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ASTHMA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ARTHITUS BOTH KNEES/DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SCHIZOPHRENIA') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SUCIDIAL/ ANXIETY/ DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DIABETIC') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HIGH CHLORESTERAL/ PAIN IN THROAT/ ANXIETY/ PANIC ATTACKS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PROBLEMS WITH LEGSPAIN AND FEET') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/BACK PROBLEMS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('MEMORY DIFFICULTIES') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/ ANXIETY/ STRESS/ GLOBAL DEVELOPMENT DELAY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('LOWER BACK PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Depression/Arthritus in both knees/Glicoma in right eye') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/ PANIC ATTACKS/ ANXIETY/ SOCIAL ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('MENTAL HEALTH/ ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ARTHARTIS MUSCLE PROBLEMS/ANIEXTY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANGER ISSUES') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY, DEPRESSION, EUPD, PTSD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY, DEPRESSION, HERNIA, PAIN IN HANDS & JOINTS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('CHRONIC PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('CHINESE OTHER SLOVAKIAN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PARANOIA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('KIDNEY AND HEART FAILURE/ MOBILITY ISSUES') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HAS BACK PROBLEMS, SLIPPED DISCS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('IBS/ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ARTHIRITIS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PSTD/DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('LOW MOODS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY/ DEPRESSION/ PTSD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SCHZOPHRENIA/ BPD/ BORDERLINE PERSONALITY DISORDER') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ATHSMATIC/ INSOMNIA/ ANXIETY/ DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HIP AND BACK PROBLEMS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PROMETHAZINE/ ADHD/ AUTISM/ BRAIN INJURY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('OCD/ANXIETY/CD/DEPRESSION/JOINT ACHES/BACK PAIN/ABDOMINAL PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PAIN IN FEET') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SCHIZOPHRENIA ON DEPO') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY/ PTSD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HOMELESS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DOMIESTIC ABUSE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PYSICAL/MENTAL HEALTH') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('MENTAL HEALTH') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('HOMELESS/DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BIPOLAR') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION/CPTSD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('NO') THEN 'NOT AVAILABLE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('N0') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('IRANIAN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ARTHRITISE KNEE PROBLEM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('NONE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY, DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ARTHRITE, DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ASTHMA, ANXIETY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('STRESS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('CHORONS DISEASE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('MEMORY LOSS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY,KNEE PROBLEM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('KNEE PROBLEM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BLIND ONE EYE,DIABETIC,CHLOSTROL,DEPRESSION') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('IBS') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PHYSICAL DISABILITY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SCHIZOPHERNIA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('SHOULDER DISABILITY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('LEG DISABILITY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ANXIETY,BACK PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BREATHING PROBLEM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BACK PROBLEM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DIEBITICS, ANGINA PAIN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PREGNANT') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('BAD DRINKING HABIT') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('None.') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Mental Health') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('No') THEN 'NOT AVAILABLE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Other') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('DEPRESSION, ANXIETY, PTSD, PERSONALITY DISORDER') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ADHD, AUTISM') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Problem with both eyes') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('anxiety, depression, ocd, osteoporisis in knee') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Bipolar type 2 and EUPD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Anxiety, Depression, PTSD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PTSD, depression, anxiety, chronic back pain, nerve damage, asthma') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('PTSD, Mixed anxiety, Depression, borderline personality disorder') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ADHD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Leaking valve in heart, Brain injury since the age of 13') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Back problems') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Heart Problems,') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Depression and anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Asmatic') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Struggles to read and write') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Cancer') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Dyslexic') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Anxiety, Depression') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Brain Tumour, Anxiety, Depression') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('asthama, ptsd, anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('depression') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Eye impairment') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('ADHD, Anxiety, depression') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Autism, OCD') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Epilepsey, depression, anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('issues with left leg') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Autism, depression, anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('IBS, depression, anxiety, bi polar, schizophrenia') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Lower back problems') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Anxiety, depression') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Depression, anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Leg pain, suspected blood clot both legs') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Depression') THEN 'A MENTAL HEALTH CONDITION, SUCH AS DEPRESSION, SCHIZOPHRENIA OR ANXIETY DISORDER'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Mental health, anxiety') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Mobiity issues, COPD, Asthama, PTSD, ADHD, Torrets') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE Disability
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET Disability = CASE
#                         WHEN Disability IN ('Bipolar, ADHD, Anixiety, Depression') THEN 'OTHER OR NON-DISCLOSURE'
# ...
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('urdu / mirpuri') THEN 'URDU'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English and Romanian') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('HETEROSEXUAL') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('ARABIC,ENGLISH,DUTCH') THEN 'ARABIC'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('TIGRINIA') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('BITISH ENGLISH') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English / Italian / French') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English,urdu') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Somaia') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Sudnase') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English,Kurdish') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Polish') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Urdu') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Somalia') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Arabic, English') THEN 'ARABIC'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Sudanese') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Pashto/Urdu') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English, Sudanese') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English. Somali') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English, Somali') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Romanian') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Somali, English') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Mexican') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('PUNJABI') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('PAKISTANI') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('BRITISH') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('UGANDAN') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('FARSI') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('SWAHILI') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('OROMO (ETHIOPIA)') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('LIMITED RESOURCES AVAILABLE') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('CZECH') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Slovakian') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Eglish') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/Arabic') THEN 'ARABIC'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Czech') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Romanian') THEN 'ROMANIAN'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('chezc /english') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Romaina') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/German') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/ Arabic') THEN 'ARABIC'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('English/ Romanian') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('english') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('english/Kurdish') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('slovakian') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Polish') THEN 'POLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('Arabic') THEN 'ARABIC'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('eNGLISH') THEN 'ENGLISH'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('DARI') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('PASHTO') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('PREFER NOT TO SAY') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('PASHTU') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
#
# Executed ->
#                     UPDATE base.yearly_tenant_data
#                     SET SpokenLanguage = CASE
#                         WHEN SpokenLanguage IN ('LOW') THEN 'OTHER OR NON-DISCLOSURE'
#                         ELSE SpokenLanguage
#                     END;
